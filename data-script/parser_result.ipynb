# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./NB1-Attrition-smi.csv')
df.head()
# Out:
#    cell_id  line_no                                               code  \
# 0        6        0  sb.catplot(y="Attrition", data=employee, kind=...
# 1       24        1  sb.swarmplot(x = 'Attrition', y = 'Age', data ...
# 2       25        1  sb.swarmplot(x = 'Attrition', y = 'YearsWithCu...
# 3       27        2  sb.catplot(y = var, data = attrition, kind = "...
# 4       27        2  sb.catplot(y = var, data = attrition, kind = "...
#
#   module_name  func_name                                          arguments  \
# 0     seaborn    catplot  {'x': '', 'y': 'Attrition', 'hue': '', 'col': ...
# 1     seaborn  swarmplot          {'x': 'Attrition', 'y': 'Age', 'hue': ''}
# 2     seaborn  swarmplot  {'x': 'Attrition', 'y': 'YearsWithCurrManager'...
# 3     seaborn    catplot  {'x': '', 'y': 'RelationshipSatisfaction', 'hu...
# 4     seaborn    catplot  {'x': '', 'y': 'Attrition', 'hue': '', 'col': ...
#
#      dataframe plottype                                      program_slice
# ...

# %%
# Parse csv into desired JSON format for react flow nodes and edges
